# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
train_df=pd.read_csv('train.csv')
test_df=pd.read_csv('test.csv')

# %%
train_df.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
# 2                          2               0                  12
# 3                          2               0                  12
# 4                         4+               0                   8
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 NaN                 NaN      8370
# 1                 6.0                14.0     15200
# ...

# %%
test_df.head()
# Out:
#    User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0  1000004  P00128942      M  46-50           7             B
# 1  1000009  P00113442      M  26-35          17             C
# 2  1000010  P00288442      F  36-45           1             B
# 3  1000010  P00145342      F  36-45           1             B
# 4  1000011  P00053842      F  26-35           1             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               1                   1
# 1                          0               0                   3
# 2                         4+               1                   5
# 3                         4+               1                   4
# 4                          1               0                   4
#
#    Product_Category_2  Product_Category_3
# 0                11.0                 NaN
# 1                 5.0                 NaN
# 2                14.0                 NaN
# ...

# %%
train_df.shape,test_df.shape
# Out:
# ((550068, 12), (233599, 11))

# %%
train_df.isnull().sum()
# Out:
# User_ID                            0
# Product_ID                         0
# Gender                             0
# Age                                0
# Occupation                         0
# City_Category                      0
# Stay_In_Current_City_Years         0
# Marital_Status                     0
# Product_Category_1                 0
# Product_Category_2            173638
# Product_Category_3            383247
# Purchase                           0
# dtype: int64

# %%
train_df=train_df.append(test_df)

# %%
train_df.shape
# Out:
# (783667, 12)

# %%
train_df.drop(columns='User_ID',axis=1,inplace=True)

# %%
train_df['Gender']=train_df['Gender'].map({'F':0,'M':1})

# %%
train_df['Gender'].head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    1
# Name: Gender, dtype: int64

# %%
train_df['Age'].unique()
# Out:
# array(['0-17', '55+', '26-35', '46-50', '51-55', '36-45', '18-25'],
#       dtype=object)

# %%
train_df['Age']=train_df['Age'].map({'0-17':1, '55+':7, '26-35':3, '46-50':5, '51-55':6, '36-45':4, '18-25':2})

# %%
train_df['Age'].head()
# Out:
# 0    1
# 1    1
# 2    1
# 3    1
# 4    7
# Name: Age, dtype: int64

# %%
train_df['City_Category'].unique()
# Out:
# array(['A', 'C', 'B'], dtype=object)

# %%
df_city=pd.get_dummies(train_df['City_Category'],drop_first=True)

# %%
df=pd.concat([df_city,train_df],axis=1)

# %%
df.drop(columns='City_Category',axis=1,inplace=True)

# %%
df.isnull().sum()
# Out:
# B                                  0
# C                                  0
# Product_ID                         0
# Gender                             0
# Age                                0
# Occupation                         0
# Stay_In_Current_City_Years         0
# Marital_Status                     0
# Product_Category_1                 0
# Product_Category_2            245982
# Product_Category_3            545809
# Purchase                      233599
# dtype: int64

# %%
df['Product_Category_2'].unique()
# Out:
# array([nan,  6., 14.,  2.,  8., 15., 16., 11.,  5.,  3.,  4., 12.,  9.,
#        10., 17., 13.,  7., 18.])

# %%
df['Product_Category_2'].value_counts()
# Out:
# 8.0     91317
# 14.0    78834
# 2.0     70498
# 16.0    61687
# 15.0    54114
# 5.0     37165
# 4.0     36705
# 6.0     23575
# 11.0    20230
# 17.0    19104
# 13.0    15054
# 9.0      8177
# 12.0     7801
# 10.0     4420
# 3.0      4123
# 18.0     4027
# 7.0       854
# Name: Product_Category_2, dtype: int64

# %%
df['Product_Category_2']=df['Product_Category_2'].fillna(df['Product_Category_2'].mode()[0])

# %%
df.isnull().sum()
# Out:
# B                                  0
# C                                  0
# Product_ID                         0
# Gender                             0
# Age                                0
# Occupation                         0
# Stay_In_Current_City_Years         0
# Marital_Status                     0
# Product_Category_1                 0
# Product_Category_2                 0
# Product_Category_3            545809
# Purchase                      233599
# dtype: int64

# %%
df['Product_Category_3'].unique()
# Out:
# array([nan, 14., 17.,  5.,  4., 16., 15.,  8.,  9., 13.,  6., 12.,  3.,
#        18., 11., 10.])

# %%
df['Product_Category_3'].value_counts()
# Out:
# 16.0    46469
# 15.0    39968
# 14.0    26283
# 17.0    23818
# 5.0     23799
# 8.0     17861
# 9.0     16532
# 12.0    13115
# 13.0     7849
# 6.0      6888
# 18.0     6621
# 4.0      2691
# 11.0     2585
# 10.0     2501
# 3.0       878
# Name: Product_Category_3, dtype: int64

# %%
df['Product_Category_3'].mode()
# Out:
# 0    16.0
# dtype: float64

# %%
df['Product_Category_3']=df['Product_Category_3'].fillna(df['Product_Category_3'].mode()[0])

# %%
df.isnull().sum()
# Out:
# B                                  0
# C                                  0
# Product_ID                         0
# Gender                             0
# Age                                0
# Occupation                         0
# Stay_In_Current_City_Years         0
# Marital_Status                     0
# Product_Category_1                 0
# Product_Category_2                 0
# Product_Category_3                 0
# Purchase                      233599
# dtype: int64

# %%
df['Stay_In_Current_City_Years'].unique()
# Out:
# array(['2', '4+', '3', '1', '0'], dtype=object)

# %%
df['Stay_In_Current_City_Years']=df['Stay_In_Current_City_Years'].str.replace('+','')
# Out:
# <ipython-input-43-7d6a3c4db74c>:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   df['Stay_In_Current_City_Years']=df['Stay_In_Current_City_Years'].str.replace('+','')

# %%
df['Stay_In_Current_City_Years']=df['Stay_In_Current_City_Years'].astype('int')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 783667 entries, 0 to 233598
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   B                           783667 non-null  uint8
#  1   C                           783667 non-null  uint8
#  2   Product_ID                  783667 non-null  object
#  3   Gender                      783667 non-null  int64
#  4   Age                         783667 non-null  int64
#  5   Occupation                  783667 non-null  int64
#  6   Stay_In_Current_City_Years  783667 non-null  int32
#  7   Marital_Status              783667 non-null  int64
#  8   Product_Category_1          783667 non-null  int64
#  9   Product_Category_2          783667 non-null  float64
#  10  Product_Category_3          783667 non-null  float64
#  11  Purchase                    550068 non-null  float64
# dtypes: float64(3), int32(1), int64(5), object(1), uint8(2)
# ...

# %%
df['B']=df['B'].astype('int')
df['C']=df['C'].astype('int')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 783667 entries, 0 to 233598
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   B                           783667 non-null  int32
#  1   C                           783667 non-null  int32
#  2   Product_ID                  783667 non-null  object
#  3   Gender                      783667 non-null  int64
#  4   Age                         783667 non-null  int64
#  5   Occupation                  783667 non-null  int64
#  6   Stay_In_Current_City_Years  783667 non-null  int32
#  7   Marital_Status              783667 non-null  int64
#  8   Product_Category_1          783667 non-null  int64
#  9   Product_Category_2          783667 non-null  float64
#  10  Product_Category_3          783667 non-null  float64
#  11  Purchase                    550068 non-null  float64
# dtypes: float64(3), int32(3), int64(5), object(1)
# ...

# %%
sns.pairplot(df)

# %%
sns.barplot('Age','Purchase',hue='Gender',data=df)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Purchase'>

# %%
plt.figure(figsize=(15,10))
sns.barplot('Occupation','Purchase',hue='Gender',data=df)
# Out:
# C:\Users\LENOVO\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Occupation', ylabel='Purchase'>

# %%
sns.barplot('Product_Category_1','Purchase',hue='Gender',data=df)
# Out:
# C:\Users\LENOVO\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Product_Category_1', ylabel='Purchase'>

# %%
sns.barplot('Product_Category_2','Purchase',hue='Gender',data=df)
# Out:
# C:\Users\LENOVO\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Product_Category_2', ylabel='Purchase'>

# %%
sns.barplot('Product_Category_3','Purchase',hue='Gender',data=df)
# Out:
# C:\Users\LENOVO\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Product_Category_3', ylabel='Purchase'>

# %%
df_train=df[~df['Purchase'].isnull()]

# %%
X=df_train.drop('Purchase',axis=1)
y=df_train['Purchase']

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.33,random_state=42)

# %%
X_train.drop('Product_ID',axis=1,inplace=True)
X_test.drop('Product_ID',axis=1,inplace=True)
# Out:
# C:\Users\LENOVO\anaconda3\lib\site-packages\pandas\core\frame.py:4308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
X_train=sc.fit_transform(X_train)
X_test=sc.transform(X_test)
